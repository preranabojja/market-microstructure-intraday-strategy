# %%
import sys
import os

# Add project root to Python path
sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.feature_engineering import add_microstructure_features
#load cleaned data
df = pd.read_csv("/Users/prerana/Documents/market-microstructure-intraday-strategy/data/raw/spy_intraday.csv")
df['timestamp'] = pd.to_datetime(df['date'])
df = df.set_index('timestamp')
df = df.between_time('09:30', '16:00')

# %%
#add features
df_feat = add_microstructure_features(df)
df_feat.head()
# Out:
#                                     date    open    high     low   close  \
# timestamp
# 2008-01-22 09:59:00  2008-01-22 09:59:00  130.14  130.21  130.03  130.13
# 2008-01-22 10:00:00  2008-01-22 10:00:00  130.13  130.27  129.98  130.04
# 2008-01-22 10:01:00  2008-01-22 10:01:00  130.03  130.17  129.98  130.11
# 2008-01-22 10:02:00  2008-01-22 10:02:00  130.11  130.36  130.04  130.36
# 2008-01-22 10:03:00  2008-01-22 10:03:00  130.36  130.47  130.31  130.46
#
#                      volume  barCount  average    return  rolling_vol  \
# timestamp
# 2008-01-22 09:59:00    7315       973  130.106  0.000000     0.001371
# 2008-01-22 10:00:00    5491       951  130.103 -0.000692     0.001380
# 2008-01-22 10:01:00    4300       780  130.064  0.000538     0.001235
# 2008-01-22 10:02:00    6536       984  130.214  0.001921     0.001352
# 2008-01-22 10:03:00    4030       683  130.393  0.000767     0.001361
#
#                       avg_volume  volume_zscore  momentum
# timestamp
# ...

# %%
#save processed data
df_feat.to_csv("../data/processed/spy_intraday_features.csv")
